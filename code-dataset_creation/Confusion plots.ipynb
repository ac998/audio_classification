# %%
from sklearn.metrics import confusion_matrix,classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y_pred = np.loadtxt('y_pred_1000.csv')
y_test = np.loadtxt('y_test_1000.csv')

# %%
print(y_pred.shape)
print(y_test.shape)
# Out:
# (4422,)
# (4422,)

# %%
conf_mat = confusion_matrix(y_test,y_pred)
print(conf_mat)
print("\n")
print(classification_report(y_test,y_pred))
# Out:
# [[ 777   56   21  213]
#  [ 331  520   42  209]
#  [  25  125 1042    0]
#  [  66    0    0  995]]
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.73      0.69      1067
#          1.0       0.74      0.47      0.58      1102
#          2.0       0.94      0.87      0.91      1192
#          3.0       0.70      0.94      0.80      1061
#
#    micro avg       0.75      0.75      0.75      4422
#    macro avg       0.76      0.75      0.74      4422
# weighted avg       0.76      0.75      0.75      4422

# %%
fig, ax = plt.subplots(figsize=(8,8))    
ax = sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels= ['Machine', 'Music', 'Speech', 'Nature'], yticklabels=['Machine', 'Music', 'Speech', 'Nature'], cmap="YlGnBu", square=True)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion matrix for classification of frames of 1000ms')
#plt.show()
plt.savefig('CM_1000_CNN.png')
